# %%
{
  "title": "System Information Collection",
  "description": "A simple form to collect basic information about your computer or device.",
  "sections": [
    {
      "title": "Device Information",
      "questions": [
        {
          "type": "short_answer",
          "label": "Device Name",
          "required": true
        },
        {
          "type": "short_answer",
          "label": "Operating System",
          "required": true
        }
      ]
    },
    {
      "title": "Hardware Details",
      "questions": [
        {
          "type": "short_answer",
          "label": "Processor Type",
          "required": false
        },
        {
          "type": "short_answer",
          "label": "RAM Size",
          "required": false
        }
      ]
    },
    {
      "title": "Software & Preferences",
      "questions": [
        {
          "type": "paragraph",
          "label": "Installed Software",
          "required": false
        },
        {
          "type": "checkbox",
          "label": "Do you want to receive system updates notifications?",
          "options": ["Yes, notify me"],
          "required": false
        }
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       1 {
#       2   "title": "System Information Collection",
#       3   "description": "A simple form to collect basic information about your computer or device.",
#       4   "sections": [
#       5     {
#       6       "title": "Device Information",
#       7       "questions": [
#       8         {
#       9           "type": "short_answer",
#      10           "label": "Device Name",
# ---> 11           "required": true
#      12         },
#      13         {
#      14           "type": "short_answer",
#      15           "label": "Operating System",
#      16           "required": true
#      17         }
#      18       ]
#      19     },
#      20     {
#      21       "title": "Hardware Details",
#      22       "questions": [
#      23         {
#      24           "type": "short_answer",
# ...

# %%
{
  "title": "System Information Collection",
  "description": "A simple form to collect basic information about your computer or device.",
  "sections": [
    {
      "title": "Device Information",
      "questions": [
        {
          "type": "short_answer",
          "label": "Device Name",
          "required": true
        },
        {
          "type": "short_answer",
          "label": "Operating System",
          "required": true
        }
      ]
    },
    {
      "title": "Hardware Details",
      "questions": [
        {
          "type": "short_answer",
          "label": "Processor Type",
          "required": false
        },
        {
          "type": "short_answer",
          "label": "RAM Size",
          "required": false
        }
      ]
    },
    {
      "title": "Software & Preferences",
      "questions": [
        {
          "type": "paragraph",
          "label": "Installed Software",
          "required": false
        },
        {
          "type": "checkbox",
          "label": "Do you want to receive system updates notifications?",
          "options": ["Yes, notify me"],
          "required": false
        }
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       1 {
#       2   "title": "System Information Collection",
#       3   "description": "A simple form to collect basic information about your computer or device.",
#       4   "sections": [
#       5     {
#       6       "title": "Device Information",
#       7       "questions": [
#       8         {
#       9           "type": "short_answer",
#      10           "label": "Device Name",
# ---> 11           "required": true
#      12         },
#      13         {
#      14           "type": "short_answer",
#      15           "label": "Operating System",
#      16           "required": true
#      17         }
#      18       ]
#      19     },
#      20     {
#      21       "title": "Hardware Details",
#      22       "questions": [
#      23         {
#      24           "type": "short_answer",
# ...

# %%
{
  "title": "System Information Collection",
  "description": "A simple form to collect basic information about your computer or device.",
  "sections": [
    {
      "title": "Device Information",
      "questions": [
        {
          "type": "short_answer",
          "label": "Device Name",
          "required": True
        },
        {
          "type": "short_answer",
          "label": "Operating System",
          "required": True
        }
      ]
    },
    {
      "title": "Hardware Details",
      "questions": [
        {
          "type": "short_answer",
          "label": "Processor Type",
          "required": False
        },
        {
          "type": "short_answer",
          "label": "RAM Size",
          "required": False
        }
      ]
    },
    {
      "title": "Software & Preferences",
      "questions": [
        {
          "type": "paragraph",
          "label": "Installed Software",
          "required": False
        },
        {
          "type": "checkbox",
          "label": "Do you want to receive system updates notifications?",
          "options": ["Yes, notify me"],
          "required": False
        }
      ]
    }
  ]
}
# Out:
# {'title': 'System Information Collection',
#  'description': 'A simple form to collect basic information about your computer or device.',
#  'sections': [{'title': 'Device Information',
#    'questions': [{'type': 'short_answer',
#      'label': 'Device Name',
#      'required': True},
#     {'type': 'short_answer', 'label': 'Operating System', 'required': True}]},
#   {'title': 'Hardware Details',
#    'questions': [{'type': 'short_answer',
#      'label': 'Processor Type',
#      'required': False},
#     {'type': 'short_answer', 'label': 'RAM Size', 'required': False}]},
#   {'title': 'Software & Preferences',
#    'questions': [{'type': 'paragraph',
#      'label': 'Installed Software',
#      'required': False},
#     {'type': 'checkbox',
#      'label': 'Do you want to receive system updates notifications?',
#      'options': ['Yes, notify me'],
#      'required': False}]}]}
