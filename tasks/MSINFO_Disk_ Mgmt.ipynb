# %%
{
  "SystemInfo": {
    "ComputerName": "DESKTOP-26BGR10",
    "UserName": "DESKTOP-26BGR10\\cash",
    "Manufacturer": "HP",
    "Model": "HP EliteBook 640 14 inch G9 Notebook PC",
    "OperatingSystem": "Microsoft Windows 10 Professionnel",
    "OSVersion": "10.0.19045 Build 19045",
    "Processor": "12th Gen Intel(R) Core(TM) i5-1245U, 1600 MHz, 10 cores",
    "BIOSVersion": "HP Q86 Ver. 01.15.00, 11-04-25",
    "SystemType": "x64-based PC",
    "BIOSMode": "UEFI"
  },
  "DiskManagement": {
    "Disk0": {
      "Status": "Online",
      "Capacity_GB": 238.46,
      "Partitions": [
        {
          "Volume": "EFI System Partition",
          "Size_MB": 100,
          "FileSystem": "FAT32",
          "Status": "Healthy (EFI System Partition)"
        },
        {
          "Volume": "C:",
          "Size_GB": 237.79,
          "FileSystem": "NTFS (BitLocker Encrypted)",
          "Status": "Healthy (Boot, Page File, Crash Dump, Primary Partition)",
          "FreeSpace_GB": 96.71
        },
        {
          "Volume": "Recovery Partition",
          "Size_MB": 560,
          "Status": "Healthy (Recovery Partition)"
        }
      ]
    }
  }
}
# Out:
# {'SystemInfo': {'ComputerName': 'DESKTOP-26BGR10',
#   'UserName': 'DESKTOP-26BGR10\\cash',
#   'Manufacturer': 'HP',
#   'Model': 'HP EliteBook 640 14 inch G9 Notebook PC',
#   'OperatingSystem': 'Microsoft Windows 10 Professionnel',
#   'OSVersion': '10.0.19045 Build 19045',
#   'Processor': '12th Gen Intel(R) Core(TM) i5-1245U, 1600 MHz, 10 cores',
#   'BIOSVersion': 'HP Q86 Ver. 01.15.00, 11-04-25',
#   'SystemType': 'x64-based PC',
#   'BIOSMode': 'UEFI'},
#  'DiskManagement': {'Disk0': {'Status': 'Online',
#    'Capacity_GB': 238.46,
#    'Partitions': [{'Volume': 'EFI System Partition',
#      'Size_MB': 100,
#      'FileSystem': 'FAT32',
#      'Status': 'Healthy (EFI System Partition)'},
#     {'Volume': 'C:',
#      'Size_GB': 237.79,
#      'FileSystem': 'NTFS (BitLocker Encrypted)',
#      'Status': 'Healthy (Boot, Page File, Crash Dump, Primary Partition)',
#      'FreeSpace_GB': 96.71},
#     {'Volume': 'Recovery Partition',
#      'Size_MB': 560,
# ...
