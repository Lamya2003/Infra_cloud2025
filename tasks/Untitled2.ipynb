# %%
#### DEVNET SANDBOX -- ALWAYS ON
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print("Connecting via SSH => show version")
#
from netmiko import ConnectHandler
### VAR

### EXEC
sshCli = ConnectHandler(
    device_type="cisco_ios",
    host="192.168.56.101",
    port="22",
    username="Enter your username",
    password="Enter your password"
    )
output=sshCli.send_command("show version")
for line in output.splitlines():
    if 'Cisco IOS Software' in line:
        ios_version = line.strip()
    elif 'uptime' in line:
        hostname = line.split()[0]
        sys_uptime = line    
    elif 'interface' in line:
        num_interfaces = line.split()[0]
print("IOS Version")
print(ios_version)
print("Hostname")
print(hostname)
print("System uptime")
print(sys_uptime)
print("Number of Interfaces")
print(num_interfaces)
# Out:
# Current date and time:
# 2025-11-12 13:36:58.272534
# Connecting via SSH => show version
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\netmiko\base_connection.py:1146, in BaseConnection.establish_connection(self, width, height)
#    1145 try:
# -> 1146     self.remote_conn_pre.connect(**ssh_connect_params)
#    1147 except socket.error as conn_error:
#
# File ~\anaconda3\Lib\site-packages\paramiko\client.py:384, in SSHClient.connect(self, hostname, port, username, password, pkey, key_filename, timeout, allow_agent, look_for_keys, compress, sock, gss_auth, gss_kex, gss_deleg_creds, gss_host, banner_timeout, auth_timeout, channel_timeout, gss_trust_dns, passphrase, disabled_algorithms, transport_factory, auth_strategy)
#     383         pass
# --> 384 sock.connect(addr)
#     385 # Break out of the loop on success
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# NetmikoTimeoutException                   Traceback (most recent call last)
# Cell In[3], line 11
#       7 from netmiko import ConnectHandler
#       8 ### VAR
#       9
#      10 ### EXEC
# ---> 11 sshCli = ConnectHandler(
#      12     device_type="cisco_ios",
#      13     host="192.168.56.101",
#      14     port="22",
#      15     username="Enter your username",
#      16     password="Enter your password"
#      17     )
#      18 output=sshCli.send_command("show version")
#      19 for line in output.splitlines():
#
# File ~\anaconda3\Lib\site-packages\netmiko\ssh_dispatcher.py:460, in ConnectHandler(*args, **kwargs)
#     455     raise ValueError(
#     456         "Unsupported 'device_type' "
#     457         "currently supported platforms are: {}".format(msg_str)
#     458     )
#     459 ConnectionClass = ssh_dispatcher(device_type)
# --> 460 return ConnectionClass(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\netmiko\base_connection.py:495, in BaseConnection.__init__(self, ip, host, username, password, secret, port, device_type, verbose, global_delay_factor, global_cmd_verify, use_keys, key_file, pkey, passphrase, disabled_algorithms, disable_sha2_fix, allow_agent, ssh_strict, system_host_keys, alt_host_keys, alt_key_file, ssh_config_file, conn_timeout, auth_timeout, banner_timeout, blocking_timeout, timeout, session_timeout, read_timeout_override, keepalive, default_enter, response_return, serial_settings, fast_cli, _legacy_mode, session_log, session_log_record_writes, session_log_file_mode, allow_auto_change, encoding, sock, sock_telnet, auto_connect, delay_factor_compat, disable_lf_normalization)
#     493 # Establish the remote connection
#     494 if auto_connect:
# --> 495     self._open()
#
# File ~\anaconda3\Lib\site-packages\netmiko\base_connection.py:500, in BaseConnection._open(self)
#     498 """Decouple connection creation from __init__ for mocking."""
#     499 self._modify_connection_params()
# --> 500 self.establish_connection()
#     501 self._try_session_preparation()
#
# File ~\anaconda3\Lib\site-packages\netmiko\base_connection.py:1168, in BaseConnection.establish_connection(self, width, height)
#    1162         msg = (
#    1163             f"DNS failure--the hostname you provided was not resolvable "
#    1164             f"in DNS: {self.host}:{self.port}"
#    1165         )
#    1167     msg = msg.lstrip()
# -> 1168     raise NetmikoTimeoutException(msg)
#    1169 except paramiko.ssh_exception.AuthenticationException as auth_err:
#    1170     self.paramiko_cleanup()
#
# NetmikoTimeoutException: TCP connection to device failed.
#
# Common causes of this problem are:
# 1. Incorrect hostname or IP address.
# 2. Wrong TCP port.
# 3. Intermediate firewall blocking access.
#
# Device settings: cisco_ios 192.168.56.101:22

# %%
# !pip install netmiko
# Out:
# Collecting netmiko
#   Downloading netmiko-4.6.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting ntc-templates>=3.1.0 (from netmiko)
#   Downloading ntc_templates-8.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting paramiko>=2.9.5 (from netmiko)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyserial>=3.3 (from netmiko)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyyaml>=6.0.2 in c:\users\cash\anaconda3\lib\site-packages (from netmiko) (6.0.2)
# Requirement already satisfied: rich>=13.8 in c:\users\cash\anaconda3\lib\site-packages (from netmiko) (13.9.4)
# Requirement already satisfied: ruamel.yaml>=0.17 in c:\users\cash\anaconda3\lib\site-packages (from netmiko) (0.18.10)
# Collecting scp>=0.13.6 (from netmiko)
#   Downloading scp-0.15.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting textfsm>=1.1.3 (from netmiko)
#   Downloading textfsm-2.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: bcrypt>=3.2 in c:\users\cash\anaconda3\lib\site-packages (from paramiko>=2.9.5->netmiko) (4.3.0)
# Requirement already satisfied: cryptography>=3.3 in c:\users\cash\anaconda3\lib\site-packages (from paramiko>=2.9.5->netmiko) (44.0.1)
# Collecting invoke>=2.0 (from paramiko>=2.9.5->netmiko)
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pynacl>=1.5 in c:\users\cash\anaconda3\lib\site-packages (from paramiko>=2.9.5->netmiko) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\cash\anaconda3\lib\site-packages (from cryptography>=3.3->paramiko>=2.9.5->netmiko) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\cash\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.9.5->netmiko) (2.21)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cash\anaconda3\lib\site-packages (from rich>=13.8->netmiko) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cash\anaconda3\lib\site-packages (from rich>=13.8->netmiko) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cash\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8->netmiko) (0.1.0)
# Downloading netmiko-4.6.0-py3-none-any.whl (262 kB)
# Downloading ntc_templates-8.1.0-py3-none-any.whl (623 kB)
#    ---------------------------------------- 0.0/623.3 kB ? eta -:--:--
#    --------------------------------------- 623.3/623.3 kB 11.3 MB/s eta 0:00:00
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Downloading scp-0.15.0-py2.py3-none-any.whl (8.8 kB)
# Downloading textfsm-2.1.0-py2.py3-none-any.whl (44 kB)
# Installing collected packages: textfsm, pyserial, ntc-templates, invoke, paramiko, scp, netmiko
#
#    ----------- ---------------------------- 2/7 [ntc-templates]
#    ----------- ---------------------------- 2/7 [ntc-templates]
#    ----------- ---------------------------- 2/7 [ntc-templates]
#    ----------------- ---------------------- 3/7 [invoke]
#    ---------------------- ----------------- 4/7 [paramiko]
#    ---------------------------------- ----- 6/7 [netmiko]
#    ---------------------------------- ----- 6/7 [netmiko]
#    ---------------------------------- ----- 6/7 [netmiko]
#    ---------------------------------- ----- 6/7 [netmiko]
#    ---------------------------------------- 7/7 [netmiko]
#
# Successfully installed invoke-2.2.1 netmiko-4.6.0 ntc-templates-8.1.0 paramiko-4.0.0 pyserial-3.5 scp-0.15.0 textfsm-2.1.0
